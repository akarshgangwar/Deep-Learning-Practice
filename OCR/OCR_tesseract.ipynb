# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\welcome\anaconda3\envs\pytorch1\lib\site-packages (0.3.10)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\welcome\anaconda3\envs\pytorch1\lib\site-packages (from pytesseract) (9.3.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\welcome\anaconda3\envs\pytorch1\lib\site-packages (from pytesseract) (22.0)

# %%
import pytesseract
import cv2

# %%
pytesseract.pytesseract.tesseract_cmd ="C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

# %%
image = cv2.imread('cc_OCR.jpg')
img_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print(pytesseract.image_to_string(img_RGB))
# Out:
# Sample Credit Card Number
#
# 4385822056110982
# 4 38582 205611 0982
# Issuer Bank Account Check
#
# Number Number Number Digits

# %%
results = pytesseract.image_to_boxes(img_RGB)
ih, iw, ic = image.shape
for box in results.splitlines():
    box = box.split(' ')
    print(box)

    x, y, w, h = int(box[1]), int(box[2]), int(box[3]), int(box[4])
    cv2.rectangle(image, (x, ih-y), (w, ih-h), (0, 255, 0), 2)
    cv2.putText(image, box[0], (x, ih-h), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 0, 0), 1)
# Out:
# ['S', '112', '263', '132', '288', '0']
# ['a', '136', '263', '157', '282', '0']
# ['m', '157', '264', '183', '282', '0']
# ['p', '182', '255', '205', '282', '0']
# ['l', '209', '264', '227', '289', '0']
# ['e', '231', '263', '252', '282', '0']
# ['C', '279', '263', '301', '288', '0']
# ['r', '304', '264', '325', '282', '0']
# ['e', '327', '263', '348', '282', '0']
# ['d', '351', '263', '374', '289', '0']
# ['i', '377', '264', '395', '289', '0']
# ['t', '401', '263', '422', '288', '0']
# ['C', '447', '263', '469', '288', '0']
# ['a', '472', '263', '493', '282', '0']
# ['r', '496', '264', '517', '282', '0']
# ['d', '519', '263', '542', '289', '0']
# ['N', '566', '264', '590', '287', '0']
# ['u', '591', '263', '613', '281', '0']
# ['m', '613', '264', '637', '282', '0']
# ['b', '637', '263', '661', '289', '0']
# ['e', '663', '263', '684', '282', '0']
# ['r', '688', '264', '709', '282', '0']
# ['4', '186', '189', '210', '223', '0']
# ['3', '216', '188', '239', '223', '0']
# ['8', '244', '188', '267', '223', '0']
# ['5', '273', '188', '295', '223', '0']
# ['8', '301', '188', '323', '223', '0']
# ['2', '328', '189', '351', '223', '0']
# ['2', '356', '189', '379', '223', '0']
# ['0', '385', '188', '407', '223', '0']
# ['5', '413', '188', '436', '223', '0']
# ['6', '441', '188', '464', '223', '0']
# ['1', '472', '189', '485', '223', '0']
# ['1', '497', '189', '510', '223', '0']
# ['0', '522', '188', '544', '223', '0']
# ['9', '550', '188', '573', '223', '0']
# ['8', '578', '188', '601', '223', '0']
# ['2', '606', '189', '629', '223', '0']
# ['4', '45', '102', '70', '143', '0']
# ['3', '157', '103', '183', '146', '0']
# ['8', '198', '103', '223', '146', '0']
# ['5', '237', '103', '263', '145', '0']
# ['8', '278', '103', '303', '146', '0']
# ['2', '316', '104', '342', '146', '0']
# ['2', '392', '104', '419', '146', '0']
# ['0', '434', '103', '459', '146', '0']
# ['5', '473', '103', '500', '145', '0']
# ['6', '516', '103', '541', '146', '0']
# ['1', '554', '104', '579', '145', '0']
# ['1', '594', '104', '619', '145', '0']
# ['0', '664', '103', '689', '146', '0']
# ['9', '706', '103', '731', '146', '0']
# ['8', '744', '103', '769', '146', '0']
# ['2', '782', '104', '809', '146', '0']
# ['I', '10', '59', '24', '78', '0']
# ['s', '29', '59', '43', '74', '0']
# ['s', '48', '59', '62', '74', '0']
# ['u', '65', '59', '83', '73', '0']
# ['e', '85', '59', '101', '74', '0']
# ['r', '105', '59', '121', '74', '0']
# ['B', '208', '54', '225', '73', '0']
# ['a', '228', '53', '244', '68', '0']
# ['n', '246', '54', '264', '68', '0']
# ['k', '266', '54', '283', '74', '0']
# ['A', '437', '55', '458', '74', '0']
# ['c', '459', '54', '475', '69', '0']
# ['c', '478', '54', '494', '69', '0']
# ['o', '497', '54', '514', '69', '0']
# ['u', '515', '54', '533', '69', '0']
# ['n', '535', '55', '552', '69', '0']
# ['t', '556', '54', '572', '74', '0']
# ['C', '680', '52', '697', '72', '0']
# ['h', '699', '52', '717', '73', '0']
# ['e', '718', '52', '735', '67', '0']
# ['c', '738', '52', '755', '67', '0']
# ['k', '757', '52', '774', '73', '0']
# ['N', '7', '19', '24', '38', '0']
# ['u', '23', '9', '41', '44', '0']
# ['m', '25', '19', '76', '39', '0']
# ['b', '58', '9', '76', '44', '0']
# ['e', '78', '19', '93', '34', '0']
# ['r', '96', '19', '110', '34', '0']
# ['N', '207', '14', '226', '33', '0']
# ['u', '226', '4', '244', '39', '0']
# ['m', '227', '13', '283', '34', '0']
# ['b', '261', '4', '282', '39', '0']
# ['e', '285', '13', '301', '28', '0']
# ['r', '305', '14', '321', '28', '0']
# ['N', '438', '15', '457', '34', '0']
# ['u', '457', '4', '475', '39', '0']
# ['m', '458', '14', '514', '35', '0']
# ['b', '492', '4', '513', '39', '0']
# ['e', '516', '14', '532', '29', '0']
# ['r', '536', '15', '552', '29', '0']
# ['D', '680', '12', '697', '31', '0']
# ['i', '700', '12', '715', '33', '0']
# ['g', '718', '6', '736', '27', '0']
# ['i', '739', '12', '754', '33', '0']
# ['t', '758', '12', '775', '31', '0']
# ['s', '777', '12', '792', '27', '0']

# %%
cv2.imshow("Input",image)
cv2.waitKey(0)
# Out:
# -1
